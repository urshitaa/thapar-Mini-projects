# %% [markdown]
# Q12. WAP to sort following number of elements in a list, calculate time taken and plot the graph.
# Number of elements in list      Time Taken
# 5k                              T1
# 10k                             T2
# 15k                             T3
# 20k                             T4
# 25k                             T5

# %%
import matplotlib.pyplot as plt 
import time 
import random

# %%
sizes = [5000, 10000, 15000, 20000, 25000]
times = []

for size in sizes: 
    data = [random.randint(1,100000) for _ in range (size)]
    start = time.time()
    sorted_data = sorted(data)
    end = time.time()
    elapsed = end - start 
    times.append(elapsed)
print("Size: {size}, time : {elpased: .6f} seconds")
print("No of elements in list | Time Taken")
for size, t in zip(sizes, times):
    print(f"| {size} \t| {t :.6f}")
# Out:
# Size: {size}, time : {elpased: .6f} seconds
# No of elements in list | Time Taken
# | 5000 	| 0.001032
# | 10000 	| 0.006300
# | 15000 	| 0.003854
# | 20000 	| 0.000000
# | 25000 	| 0.007025

# %%
plt.figure(figsize= (10,6))
plt.plot(sizes, times, 'bo-')
plt.title('Total Time Taken')
plt.xlabel('No of elements in list')
plt.ylabel('Time Taken in seconds')
plt.grid('True')
plt.show()
